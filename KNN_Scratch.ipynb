# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r'D:\21bad014_ML\new_forest_full_dataset.csv')
df
# Out:
#      day  month  year          Region  Temperature   RH   Ws  Rain   FFMC  \
# 0      1      6  2012          Bejaia           29   57   18    0.0  65.7
# 1      2      6  2012          Bejaia           29   61   13    1.3  64.4
# 2      3      6  2012          Bejaia           26   82   22   13.1  47.1
# 3      4      6  2012          Bejaia           25   89   13    2.5  28.6
# 4      5      6  2012          Bejaia           27   77   16    0.0  64.8
# ..   ...    ...   ...             ...          ...  ...  ...    ...   ...
# 239   26      9  2012  Sidi-Bel-Abbes           30   65   14    0.0  85.4
# 240   27      9  2012  Sidi-Bel-Abbes           28   87   15    4.4  41.1
# 241   28      9  2012  Sidi-Bel-Abbes           27   87   29    0.5  45.9
# 242   29      9  2012  Sidi-Bel-Abbes           24   54   18    0.1  79.7
# 243   30      9  2012  Sidi-Bel-Abbes           24   64   15    0.2  67.3
#
#       DMC    DC  ISI   BUI  FWI Classes
# 0     3.4   7.6  1.3   3.4  0.5     no
# ...

# %%
df.columns=df.columns.str.strip()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Region']=le.fit_transform(df['Region'])
reg_map = dict(zip(le.classes_, range(len(le.classes_))))
print(reg_map)
# Out:
# {'Bejaia': 0, 'Sidi-Bel-Abbes': 1}

# %%
df
# Out:
#      day  month  year  Region  Temperature  RH  Ws  Rain  FFMC   DMC    DC  \
# 0      1      6  2012       0           29  57  18   0.0  65.7   3.4   7.6
# 1      2      6  2012       0           29  61  13   1.3  64.4   4.1   7.6
# 2      3      6  2012       0           26  82  22  13.1  47.1   2.5   7.1
# 3      4      6  2012       0           25  89  13   2.5  28.6   1.3   6.9
# 4      5      6  2012       0           27  77  16   0.0  64.8   3.0  14.2
# ..   ...    ...   ...     ...          ...  ..  ..   ...   ...   ...   ...
# 239   26      9  2012       1           30  65  14   0.0  85.4  16.0  44.5
# 240   27      9  2012       1           28  87  15   4.4  41.1   6.5   8.0
# 241   28      9  2012       1           27  87  29   0.5  45.9   3.5   7.9
# 242   29      9  2012       1           24  54  18   0.1  79.7   4.3  15.2
# 243   30      9  2012       1           24  64  15   0.2  67.3   3.8  16.5
#
#      ISI   BUI  FWI Classes
# 0    1.3   3.4  0.5   no
# ...

# %%
df['Classes']=df['Classes'].str.strip()
df['Classes'].value_counts()
# Out:
# yes    138
# no     106
# Name: Classes, dtype: int64

# %%
import math
from sklearn.metrics import accuracy_score
def cal_dist(p1,p2,ch):
    cord=len(p1)
    dis=0
    if(ch==1):
        #manhattan
        for i in range(cord):
            dis+=abs(p1[i]-p2[i])
    elif(ch==2):
        #euclidean
        for i in range(cord):
            dis+=(p1[i]-p2[i])**2
        dis=math.sqrt(dis)
    #print(dis)
    return dis

def knn(test_instance,dis_choice):
    lis=[]
    for k,v in train_dict.items():
        d=cal_dist(k,test_instance,dis_choice)
        lis.append([k,v,d])
    #print(lis)
    lis.sort(key=lambda x:x[2])
    #print(lis)
    final_class_list=[lis[j][1] for j in range(kval)]
    return max(final_class_list,key=final_class_list.count)

def train_test_split(data):
    train_size=float(input("Enter train ratio of split in decimals"))
    rec_index=int(len(data)*train_size)
    train_data=lis[:rec_index]
    test_data=lis[rec_index:]
    print(len(train_data),len(test_data))
    return train_data,test_data

def convert_to_dict(train_data,test_data):
    for i in train_data:
        key=tuple(i[:-1])
        val=i[-1]
        train_dict[key]=val
    print(len(train_dict))                 # train_dict has the entire data points for training 

    print()
    #convert this test array into that of dict

    for i in test_data:
        key=tuple(i[:-1])
        val=i[-1]
        test_dict[key]=val
    #print(test_dict)  
    print(len(test_dict))
    
def predict(kval,ch,flag):
    if(flag==1): #testing on test data
        pred=[]
        actual_class=list(test_dict.values())
        print(actual_class)
        for k,v in test_dict.items():
            print(k)
            pred_class=knn(k,ch)
            pred.append(pred_class)
        print(pred)
        print(accuracy_score(y_true=actual_class,y_pred=pred))
    else:   #testing on train data
        pred=[]
        actual_class=list(train_dict.values())
        print(actual_class)
        for k,v in train_dict.items():
            print(k)
            pred_class=knn(k,ch)
            pred.append(pred_class)
        print(pred)
        print(accuracy_score(y_true=actual_class,y_pred=pred))

train_dict={}
test_dict={}
lis=np.asarray(df)
print(lis)
train,test=train_test_split(lis)
convert_to_dict(train,test)
#print(train_dict)
print()
#print(test_dict)
kval=int(input("Enter the k value"))
ch=int(input("Enter the choice of distance"))
flag=int(input("Enter choice of testing 1.On test data\n2.On train data"))
predict(kval,ch,flag)
# Out:
# [[1 6 2012 ... 3.4 0.5 'no']
#  [2 6 2012 ... 3.9 0.4 'no']
#  [3 6 2012 ... 2.7 0.1 'no']
#  ...
#  [28 9 2012 ... 3.4 0.2 'no']
#  [29 9 2012 ... 5.1 0.7 'no']
#  [30 9 2012 ... 4.8 0.5 'no']]
# Enter train ratio of split in decimals0.8
# 195 49
# 195
#
# 49
#
# Enter the k value5
# Enter the choice of distance2
# Enter choice of testing 1.On test data
# 2.On train data2
# ...
