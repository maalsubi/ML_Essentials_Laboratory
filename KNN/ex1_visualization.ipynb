# %%
import pandas as pd

# %%
df=pd.read_csv(r'D:\21bad014_ML\new_forest_full_dataset.csv')
df
# Out:
#      day  month  year          Region  Temperature   RH   Ws  Rain   FFMC  \
# 0      1      6  2012          Bejaia           29   57   18    0.0  65.7
# 1      2      6  2012          Bejaia           29   61   13    1.3  64.4
# 2      3      6  2012          Bejaia           26   82   22   13.1  47.1
# 3      4      6  2012          Bejaia           25   89   13    2.5  28.6
# 4      5      6  2012          Bejaia           27   77   16    0.0  64.8
# ..   ...    ...   ...             ...          ...  ...  ...    ...   ...
# 239   26      9  2012  Sidi-Bel-Abbes           30   65   14    0.0  85.4
# 240   27      9  2012  Sidi-Bel-Abbes           28   87   15    4.4  41.1
# 241   28      9  2012  Sidi-Bel-Abbes           27   87   29    0.5  45.9
# 242   29      9  2012  Sidi-Bel-Abbes           24   54   18    0.1  79.7
# 243   30      9  2012  Sidi-Bel-Abbes           24   64   15    0.2  67.3
#
#       DMC    DC  ISI   BUI  FWI Classes
# 0     3.4   7.6  1.3   3.4  0.5     no
# ...

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Region', 'Temperature', ' RH', ' Ws', 'Rain ',
#        'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
df.columns=df.columns.str.strip()

# %%
df['Classes'].value_counts()
# Out:
# yes        131
# no         101
# yes          5
# yes          2
# no           2
# no           1
# no           1
# no           1
# Name: Classes, dtype: int64

# %%
df['Classes']=df['Classes'].str.strip()
df['Classes'].value_counts()
# Out:
# yes    138
# no     106
# Name: Classes, dtype: int64

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Region         0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# dtype: int64

# %%
# Plotting 
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot(data=df,x=df['Temperature'],kind='kde')
plt.title("Kernel Density estimate of temperature")
plt.show()

# %%
sns.displot(data=df,x=df['Temperature'],kind='hist',hue='Region')
plt.show()

# %%
sns.lineplot(data=df,x=df['Temperature'],y=df['Ws'])
plt.show()

# %%
sns.barplot(data=df,x=df['Classes'],y=df['Temperature'],hue='Region')
plt.show()

# %%
sns.countplot(data=df,x=df['Rain'])
plt.show()

# %%
sns.boxplot(data=df,x=df['RH'],y=df['Classes'],hue='Region')
plt.show()

# %%
sns.violinplot(data=df,x=df['Ws'],y=df['Classes'],hue='Region')
plt.show()
